# %%
feats_all_names = ['HOMO (eV)',
 'LUMO (eV)',
 'DM',
 'NVE',
 'TPSA',
 'Mw',
 'NHA',
 'BertzCT',
 'AMW',
 'Me',
 'Mi',
 'nBM',
 'SCBO',
 'RBN',
 'RBF',
 'nDB',
 'nTB',
 'nN',
 'nO',
 'nP',
 'nS',
 'nF',
 'nCL',
 'nHM',
 'nHet',
 'nX',
 'C%',
 'N%',
 'O%',
 'X%',
 'nCIC',
 'Rbrid',
 'MCD',
 'nR03',
 'nR04',
 'nR05',
 'nR06',
 'D/Dtr06',
 'ZM1Kup',
 'ZM1Mad',
 'Qindex',
 'DBI',
 'HNar',
 'Xt',
 'Ram',
 'SPI',
 'DECC',
 'CENT',
 'GMTIV',
 'Wap',
 'S3K',
 'PW2',
 'PW3',
 'PW4',
 'PW5',
 'MAXDN',
 'MAXDP',
 'Psi_i_s',
 'Psi_i_A',
 'Psi_i_t',
 'Psi_i_0d',
 'Psi_e_t',
 'BAC',
 'LOC',
 'MWC06',
 'SRW05',
 'MPC06',
 'piPC07',
 'piPC10',
 'AAC',
 'IDDE',
 'IVDE',
 'Xindex',
 'Yindex',
 'IC1',
 'IC2',
 'SIC0',
 'SIC1',
 'SIC2',
 'SIC3',
 'SIC4',
 'CIC2',
 'CIC3',
 'CIC4',
 'CIC5',
 'ATS1m',
 'ATS3m',
 'ATS6m',
 'ATS8m',
 'ATS3e',
 'ATS5e',
 'ATS6e',
 'ATSC1m',
 'ATSC7m',
 'ATSC1e',
 'ATSC2e',
 'ATSC3e',
 'ATSC4e',
 'ATSC5e',
 'ATSC6e',
 'ATSC7e',
 'MATS1m',
 'MATS2m',
 'MATS3m',
 'MATS4m',
 'MATS5m',
 'MATS6m',
 'MATS7m',
 'MATS1v',
 'MATS2v',
 'MATS3v',
 'MATS4v',
 'MATS6v',
 'MATS1e',
 'MATS2e',
 'MATS3e',
 'MATS4e',
 'MATS5e',
 'MATS6e',
 'MATS7e',
 'MATS8e',
 'MATS1p',
 'MATS2p',
 'MATS3p',
 'MATS4p',
 'MATS5p',
 'MATS1i',
 'MATS4i',
 'MATS5i',
 'MATS6i',
 'MATS7i',
 'MATS8i',
 'GATS1m',
 'GATS2m',
 'GATS3m',
 'GATS4m',
 'GATS5m',
 'GATS6m',
 'GATS7m',
 'GATS8m',
 'GATS1v',
 'GATS2v',
 'GATS3v',
 'GATS4v',
 'GATS5v',
 'GATS1e',
 'GATS2e',
 'GATS3e',
 'GATS4e',
 'GATS5e',
 'GATS6e',
 'GATS7e',
 'GATS8e',
 'GATS1p',
 'GATS4p',
 'GATS5p',
 'GATS6p',
 'GATS7p',
 'GATS1i',
 'GATS2i',
 'GATS3i',
 'GATS4i',
 'GATS6i',
 'GGI3',
 'GGI4',
 'GGI5',
 'GGI6',
 'GGI8',
 'GGI10',
 'JGI1',
 'JGI2',
 'JGI3',
 'JGI4',
 'JGI5',
 'JGI6',
 'JGI7',
 'JGI9',
 'JGT',
 'SpMax1_Bh(m)',
 'SpMax2_Bh(m)',
 'SpMax4_Bh(m)',
 'SpMax5_Bh(m)',
 'SpMax6_Bh(m)',
 'SpMax1_Bh(v)',
 'SpMax3_Bh(v)',
 'SpMax8_Bh(i)',
 'SpMin1_Bh(m)',
 'SpMin4_Bh(m)',
 'SpMin6_Bh(m)',
 'SpMin8_Bh(m)',
 'SpMin7_Bh(i)',
 'SPAM',
 'MEcc',
 'SPH',
 'ASP',
 'PJI3',
 'L/Bw',
 'DISPm',
 'DISPv',
 'DISPe',
 'DISPp',
 'DISPi',
 'ChiA_G',
 'J_G',
 'VE1_RG',
 'VR2_RG',
 'Chi_G/D',
 'SpMaxA_G/D',
 'TDB03u',
 'TDB04u',
 'TDB05u',
 'TDB01m',
 'TDB02m',
 'TDB03m',
 'TDB04m',
 'TDB05m',
 'TDB06m',
 'TDB10m',
 'TDB02e',
 'TDB03p',
 'TDB04p',
 'TDB05p',
 'RDF020u',
 'RDF025u',
 'RDF030u',
 'RDF035u',
 'RDF040u',
 'RDF045u',
 'RDF060u',
 'RDF070u',
 'RDF100u',
 'RDF105u',
 'RDF140u',
 'RDF020m',
 'RDF025m',
 'RDF030m',
 'RDF035m',
 'RDF040m',
 'RDF045m',
 'RDF050m',
 'RDF055m',
 'RDF060m',
 'RDF070m',
 'RDF080m',
 'RDF085m',
 'RDF105m',
 'RDF140m',
 'RDF155m',
 'RDF030v',
 'RDF020p',
 'Mor06u',
 'Mor07u',
 'Mor08u',
 'Mor09u',
 'Mor10u',
 'Mor11u',
 'Mor13u',
 'Mor14u',
 'Mor15u',
 'Mor16u',
 'Mor18u',
 'Mor20u',
 'Mor22u',
 'Mor23u',
 'Mor24u',
 'Mor25u',
 'Mor26u',
 'Mor27u',
 'Mor28u',
 'Mor29u',
 'Mor30u',
 'Mor32u',
 'Mor02m',
 'Mor03m',
 'Mor04m',
 'Mor05m',
 'Mor06m',
 'Mor07m',
 'Mor08m',
 'Mor09m',
 'Mor10m',
 'Mor11m',
 'Mor12m',
 'Mor13m',
 'Mor14m',
 'Mor15m',
 'Mor16m',
 'Mor17m',
 'Mor18m',
 'Mor19m',
 'Mor20m',
 'Mor21m',
 'Mor22m',
 'Mor23m',
 'Mor24m',
 'Mor25m',
 'Mor26m',
 'Mor27m',
 'Mor28m',
 'Mor29m',
 'Mor30m',
 'Mor31m',
 'Mor32m',
 'Mor02v',
 'Mor03v',
 'Mor04v',
 'Mor08v',
 'Mor09v',
 'Mor11v',
 'Mor13v',
 'Mor14v',
 'Mor16v',
 'Mor18v',
 'Mor22v',
 'Mor23v',
 'Mor24v',
 'Mor25v',
 'Mor27v',
 'Mor28v',
 'Mor29v',
 'Mor30v',
 'Mor31v',
 'Mor06p',
 'Mor07p',
 'Mor08p',
 'Mor10p',
 'Mor15p',
 'Mor26p',
 'Mor32p',
 'Mor12i',
 'Mor31i',
 'L2u',
 'L3u',
 'P1u',
 'P2u',
 'G1u',
 'G2u',
 'G3u',
 'E1u',
 'E2u',
 'E3u',
 'P2m',
 'G1m',
 'G2m',
 'E1m',
 'E2m',
 'E3m',
 'E1v',
 'E2v',
 'E3v',
 'E1e',
 'E2e',
 'E1p',
 'E2p',
 'Gu',
 'Dm',
 'Dp',
 'Di',
 'ISH',
 'HGM',
 'H4u',
 'H5u',
 'H6u',
 'H7u',
 'H8u',
 'HATS1u',
 'HATS3u',
 'HATS4u',
 'HATS6u',
 'HATS7u',
 'HATS8u',
 'H1m',
 'H2m',
 'H3m',
 'H4m',
 'H6m',
 'H8m',
 'HTm',
 'HATS4m',
 'HATS3v',
 'HATS4v',
 'HATSe',
 'HATS4p',
 'HATS5p',
 'H0i',
 'HATS5i',
 'HTs',
 'HATSs',
 'RARS',
 'R3u',
 'R4u',
 'R6u',
 'R1u+',
 'R2u+',
 'R3u+',
 'R4u+',
 'R5u+',
 'R6u+',
 'R7u+',
 'R8u+',
 'RTu+',
 'R4m',
 'R5m',
 'R6m',
 'RTm',
 'R3m+',
 'R4m+',
 'R5m+',
 'R6m+',
 'R1v',
 'R2v',
 'R3v',
 'R4v',
 'R1v+',
 'R4v+',
 'R7v+',
 'RTv+',
 'R1e',
 'R2e',
 'R2e+',
 'R1p+',
 'R4p+',
 'R5p+',
 'R6p+',
 'R2i',
 'RTs+',
 'SHP2',
 'nCp',
 'nCs',
 'nCt',
 'nCq',
 'nCrs',
 'nCconj',
 'nRCOOH',
 'nRCOOR',
 'nArCOOR',
 'nRCONR2',
 'nRCOX',
 'nArCOX',
 'nRCO',
 'nArCO',
 'nCONN',
 'nC=O(O)2',
 'nRNH2',
 'nArNH2',
 'nRNHR',
 'nRNR2',
 'nRCN',
 'nRNO2',
 'nROH',
 'nOHp',
 'nOHs',
 'nOHt',
 'nROR',
 'nArOR',
 'nRSR',
 'nSO',
 'nS(=O)2',
 'nPO4',
 'nP(=O)R3/nPR5',
 'nCH2RX',
 'nCRX3',
 'nCXr',
 'nOxolanes',
 'nPyridines',
 'nHDon',
 'nHAcc',
 'nHBonds',
 'C-003',
 'C-005',
 'C-006',
 'C-007',
 'C-008',
 'C-009',
 'C-011',
 'C-013',
 'C-025',
 'C-026',
 'C-040',
 'C-041',
 'H-046',
 'H-047',
 'H-048',
 'H-049',
 'H-051',
 'H-052',
 'O-057',
 'O-058',
 'O-059',
 'O-060',
 'O-061',
 'N-067',
 'N-068',
 'N-069',
 'N-072',
 'N-075',
 'N-076',
 'F-083',
 'F-085',
 'Cl-087',
 'Cl-088',
 'Cl-089',
 'Cl-090',
 'S-109',
 'P-116',
 'P-120',
 'SdsCH',
 'SsssCH',
 'SdssC',
 'SaasC',
 'SssssC',
 'SsNH2',
 'SddsN',
 'SdssS',
 'NsCH3',
 'NdsCH',
 'NsssCH',
 'NdssC',
 'NssssC',
 'NssNH',
 'NssO',
 'CATS2D_02_DD',
 'CATS2D_03_DD',
 'CATS2D_02_DA',
 'CATS2D_02_DL',
 'CATS2D_03_DL',
 'CATS2D_04_DL',
 'CATS2D_05_DL',
 'CATS2D_06_DL',
 'CATS2D_07_DL',
 'CATS2D_02_AA',
 'CATS2D_03_AA',
 'CATS2D_02_AL',
 'CATS2D_03_AL',
 'CATS2D_04_AL',
 'CATS2D_05_AL',
 'CATS2D_06_AL',
 'CATS2D_07_AL',
 'CATS2D_02_PL',
 'CATS2D_03_PL',
 'CATS2D_01_NL',
 'CATS2D_02_LL',
 'CATS2D_03_LL',
 'CATS2D_04_LL',
 'CATS2D_05_LL',
 'CATS2D_06_LL',
 'CATS2D_07_LL',
 'T(N..Cl)',
 'T(O..O)',
 'T(O..Cl)',
 'T(Cl..Cl)',
 'B01[C-C]',
 'B01[C-N]',
 'B01[C-O]',
 'B01[C-S]',
 'B01[C-P]',
 'B01[C-F]',
 'B01[C-Cl]',
 'B01[N-O]',
 'B01[S-Cl]',
 'B01[P-Cl]',
 'B02[C-C]',
 'B02[C-N]',
 'B02[C-O]',
 'B02[C-S]',
 'B02[C-Cl]',
 'B02[N-N]',
 'B02[N-O]',
 'B02[O-O]',
 'B02[O-Cl]',
 'B03[C-C]',
 'B03[C-N]',
 'B03[C-O]',
 'B03[C-S]',
 'B03[C-P]',
 'B03[C-F]',
 'B03[C-Cl]',
 'B03[O-O]',
 'B03[O-Cl]',
 'B03[Cl-Cl]',
 'B04[C-C]',
 'B04[C-N]',
 'B04[C-O]',
 'B04[C-P]',
 'B04[C-Cl]',
 'B04[O-O]',
 'B05[C-C]',
 'B05[C-N]',
 'B05[C-O]',
 'B05[C-Cl]',
 'B06[C-N]',
 'B06[C-O]',
 'B07[C-O]',
 'B10[C-O]',
 'F01[C-O]',
 'F01[C-P]',
 'F01[C-Cl]',
 'F01[O-S]',
 'F01[O-P]',
 'F02[C-C]',
 'F02[C-N]',
 'F02[C-O]',
 'F02[C-Cl]',
 'F02[O-Cl]',
 'F02[Cl-Cl]',
 'F03[C-C]',
 'F03[C-O]',
 'F03[O-Cl]',
 'F04[C-N]',
 'F04[C-O]',
 'F04[C-Cl]',
 'F05[C-N]',
 'F05[C-O]',
 'F06[C-N]',
 'F10[C-O]',
 'Ui',
 'Hy',
 'TPSA(NO)',
 'TPSA(Tot)',
 'MLOGP',
 'MLOGP2',
 'DLS_01',
 'DLS_02',
 'DLS_03',
 'DLS_04',
 'DLS_05',
 'DLS_06',
 'DLS_cons',
 'LLS_01',
 'LLS_02']

# %%
import pandas as pd

feats_names_df = pd.read_csv('model_features_importance.csv')
feats_names = feats_names_df['DecisionTreeRegressor'].to_list()

feats_names_order = []

for feat in feats_all_names:
    if feat in feats_names:
        feats_names_order.append(feat)
print(len(feats_names_order))
feats_names_order
# Out:
# 80
# ['HOMO (eV)',
#  'LUMO (eV)',
#  'DM',
#  'TPSA',
#  'AMW',
#  'Me',
#  'nBM',
#  'nTB',
#  'nN',
#  'nO',
#  'nHM',
#  'nHet',
#  'nX',
#  'N%',
#  'O%',
#  'X%',
#  'Psi_i_A',
#  'AAC',
#  'SIC1',
#  'CIC2',
#  'ATSC1m',
#  'MATS1m',
#  'GATS1m',
#  'GATS2m',
#  'GATS1v',
#  'GATS1e',
#  'GATS2e',
#  'GATS1p',
#  'DISPm',
#  'DISPv',
#  'DISPe',
#  'DISPp',
#  'VR2_RG',
#  'Chi_G/D',
#  'TDB03m',
#  'RDF020u',
#  'RDF020p',
#  'Mor07m',
#  'Mor12m',
#  'Mor27m',
#  'Mor29m',
#  'E1m',
#  'E3v',
#  'HATS5p',
#  'HATSs',
#  'RARS',
#  'R4u',
#  'R1v+',
#  'RTv+',
#  'R1e',
#  'R1p+',
#  'RTs+',
#  'nCt',
#  'nROH',
#  'nRSR',
#  'nHDon',
#  'nHAcc',
#  'C-011',
#  'C-040',
#  'H-049',
#  'H-052',
#  'NdssC',
#  'CATS2D_02_DL',
#  'CATS2D_03_DL',
#  'CATS2D_02_AL',
#  'B01[C-N]',
#  'B01[C-O]',
#  'B01[C-S]',
#  'B02[C-O]',
#  'B03[C-N]',
#  'B05[C-O]',
#  'F01[C-O]',
#  'F02[C-O]',
#  'Ui',
#  'Hy',
#  'TPSA(Tot)',
#  'DLS_04',
#  'DLS_05',
#  'DLS_cons',
#  'LLS_02']

# %%
import pandas as pd
df = pd.DataFrame()
df['selected'] = feats_names_order

df.T.to_csv('selected_T.csv')

# %%
import warnings
import pandas as pd
import numpy as np
import joblib
from sklearn.linear_model import LinearRegression, RidgeCV
from sklearn.ensemble import GradientBoostingRegressor, ExtraTreesRegressor, StackingRegressor
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Ignore all warnings  
warnings.filterwarnings("ignore")  

sns.set_style(style='darkgrid')
# Load the data
data = pd.read_excel('data3-ml.xlsx', index_col=0)
data.fillna(0, inplace=True)

data_pred = pd.read_excel('new_data_ml.xlsx', index_col=0)
X = data.drop(['Training set value'], axis=1).to_numpy()
y = data['Training set value'].to_numpy()

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X) 

def get_three_base_models():
    three_base_models = [
        ('LinearRegression', LinearRegression()),
        ('GradientBoostingRegressor', GradientBoostingRegressor()),
        ('ExtraTreesRegressor', ExtraTreesRegressor(n_estimators=100, n_jobs=-1))
    ]
    return three_base_models

three_base_models = get_three_base_models()

# Defining the Metamodel
final_estimator = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1, 5, 10]) 
stacking_regressor = StackingRegressor(estimators=three_base_models, final_estimator=final_estimator, cv=5, n_jobs=-1)

# Run 100 iterations and store predictions
num_iterations = 1000
predictions = np.zeros((data_pred.shape[0], num_iterations))

for i in range(num_iterations):
    stacking_regressor.fit(data[feats_names_order].values, y)
    predictions[:, i] = stacking_regressor.predict(data_pred[feats_names_order].values)

# Calculate the average prediction
average_prediction = predictions.mean(axis=1)

# Save Model
joblib.dump(stacking_regressor, 'stacking_model.joblib')

# Save the predictions to a DataFrame and CSV
df = pd.DataFrame()
df['prediction'] = average_prediction
df.to_csv('selected_prediction.csv', index=False)

average_prediction
# Out:
# array([18.72979733, 19.24472082, 21.61199493, 12.27536174, 18.14470407,
#        24.83357614, 27.14994451, 29.31783843, 16.48942718, 34.48674337])
